# %%
import polars as pl
from lets_plot import *

# %%
LetsPlot.setup_html(no_js=True)

# %%
years = range(1880, 2011)
bb = []
for year in years:
    dta = pl.read_csv(f"./data/yob{year}.csv", has_header=False)
    dta = dta.with_columns(year=year)
    bb.append(dta)

babynames = pl.concat(bb)
babynames = babynames.rename(
    {"column_1": "name", "column_2": "sex", "column_3": "births"}
)

# %%
babynames.shape
# Out:
# (1690784, 4)

# %%
babynames.head()
# Out:
# shape: (5, 4)
# ┌───────────┬─────┬────────┬──────┐
# │ name      ┆ sex ┆ births ┆ year │
# │ ---       ┆ --- ┆ ---    ┆ ---  │
# │ str       ┆ str ┆ i64    ┆ i32  │
# ╞═══════════╪═════╪════════╪══════╡
# │ Mary      ┆ F   ┆ 7065   ┆ 1880 │
# │ Anna      ┆ F   ┆ 2604   ┆ 1880 │
# │ Emma      ┆ F   ┆ 2003   ┆ 1880 │
# │ Elizabeth ┆ F   ┆ 1939   ┆ 1880 │
# │ Minnie    ┆ F   ┆ 1746   ┆ 1880 │
# └───────────┴─────┴────────┴──────┘

# %% [markdown]
# ### Total births by sex and year

# %%
total_births = babynames.group_by(["year", "sex"]).agg(
    count_births=pl.col("births").sum()
)

# %%
(
    ggplot(total_births, aes(x="year", y="count_births", color="sex"))
    + geom_line(size=1)
    + scale_y_continuous(name="")
    + scale_x_continuous(format="0.0f")
    + scale_color_manual(values=["darkgreen", "orange"])
    + labs(title="Total births by sex and year")
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #p54ps2z .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .legend-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .legend-item {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .axis-title-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .axis-text-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dY5CNTG .axis-tooltip-text-x {
#    fill: #ffffff;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .axis-title-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .axis-text-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dY5CNTG .axis-tooltip-text-y {
#    fill: #ffffff;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .facet-strip-text-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #p54ps2z .facet-strip-text-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dY5CNTG .tooltip-text {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dY5CNTG .tooltip-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: bold;
#    font-style: normal;
# }
# #dY5CNTG .tooltip-label {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: bold;
#    font-style: normal;
# }
#
#   </style>
#   <g id="p54ps2z">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(23.0 34.0 ) ">
#       <g transform="translate(72.01121880696743 0.0 ) ">
#         <line x1="19.846954499456842" y1="320.0" x2="19.846954499456842" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="80.9145068054795" y1="320.0" x2="80.9145068054795" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="141.98205911150126" y1="320.0" x2="141.98205911150126" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="203.04961141752392" y1="320.0" x2="203.04961141752392" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="264.1171637235457" y1="320.0" x2="264.1171637235457" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="325.18471602956834" y1="320.0" x2="325.18471602956834" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="386.252268335591" y1="320.0" x2="386.252268335591" y2="5.684341886080801E-14" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#       </g>
#       <g transform="translate(72.01121880696743 320.0 ) ">
#         <g transform="translate(19.846954499456842 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1880</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(80.9145068054795 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1900</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(141.98205911150126 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1920</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(203.04961141752392 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1940</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(264.1171637235457 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1960</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(325.18471602956834 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1980</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(386.252268335591 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>2000</tspan>
#             </text>
#           </g>
#         </g>
#         <line x1="0.0" y1="0.0" x2="436.6329989880594" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
#         </line>
#       </g>
#       <g transform="translate(72.01121880696743 0.0 ) ">
#         <line x1="0.0" y1="247.8194481128748" x2="436.6329989880587" y2="247.8194481128748" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="0.0" y1="177.36209977694088" x2="436.6329989880587" y2="177.36209977694088" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="0.0" y1="106.90475144100694" x2="436.6329989880587" y2="106.90475144100694" stroke="rgb(233,233,233)" stroke-opacity=

# %% [markdown]
# * fraction of babies given each name relative to the total number of births

# %%
babynames = babynames.with_columns(
    prop=(pl.col("births") / pl.col("births").sum()).over(["year", "sex"])
)

# %%
babynames.head()
# Out:
# shape: (5, 5)
# ┌───────────┬─────┬────────┬──────┬──────────┐
# │ name      ┆ sex ┆ births ┆ year ┆ prop     │
# │ ---       ┆ --- ┆ ---    ┆ ---  ┆ ---      │
# │ str       ┆ str ┆ i64    ┆ i32  ┆ f64      │
# ╞═══════════╪═════╪════════╪══════╪══════════╡
# │ Mary      ┆ F   ┆ 7065   ┆ 1880 ┆ 0.077643 │
# │ Anna      ┆ F   ┆ 2604   ┆ 1880 ┆ 0.028618 │
# │ Emma      ┆ F   ┆ 2003   ┆ 1880 ┆ 0.022013 │
# │ Elizabeth ┆ F   ┆ 1939   ┆ 1880 ┆ 0.021309 │
# │ Minnie    ┆ F   ┆ 1746   ┆ 1880 ┆ 0.019188 │
# └───────────┴─────┴────────┴──────┴──────────┘

# %%
top1000 = (
    babynames.with_columns(rn=pl.col("births").rank(descending=True).over(["year", "sex"]))
    .filter(pl.col("rn") <= 1000)
    .drop("rn")
)

# %%
top1000.head()
# Out:
# shape: (5, 5)
# ┌───────────┬─────┬────────┬──────┬──────────┐
# │ name      ┆ sex ┆ births ┆ year ┆ prop     │
# │ ---       ┆ --- ┆ ---    ┆ ---  ┆ ---      │
# │ str       ┆ str ┆ i64    ┆ i32  ┆ f64      │
# ╞═══════════╪═════╪════════╪══════╪══════════╡
# │ Mary      ┆ F   ┆ 7065   ┆ 1880 ┆ 0.077643 │
# │ Anna      ┆ F   ┆ 2604   ┆ 1880 ┆ 0.028618 │
# │ Emma      ┆ F   ┆ 2003   ┆ 1880 ┆ 0.022013 │
# │ Elizabeth ┆ F   ┆ 1939   ┆ 1880 ┆ 0.021309 │
# │ Minnie    ┆ F   ┆ 1746   ┆ 1880 ┆ 0.019188 │
# └───────────┴─────┴────────┴──────┴──────────┘

# %%
total_births_top1000 = (
    top1000.group_by(["year", "name"])
    .agg(
        total_births=pl.col("births").sum()
    )
)

# %%
selected_names = total_births_top1000.filter(pl.col("name").is_in(["John", "Harry", "Mary", "Marilyn"]))

# %%
(
    ggplot(selected_names, aes(x="year", y="total_births", color="name"))
    + geom_line(show_legend=False, size=1)
    + scale_x_continuous(format="0.0f")
    + facet_wrap(facets="name", scales="free_y", ncol=1)
    + ggsize(600, 800)
    + labs(title="Number of births each year", y="")
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="800.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pPv2usC .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .legend-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .legend-item {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .axis-title-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .axis-text-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dp7V3ET .axis-tooltip-text-x {
#    fill: #ffffff;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .axis-title-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .axis-text-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dp7V3ET .axis-tooltip-text-y {
#    fill: #ffffff;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .facet-strip-text-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pPv2usC .facet-strip-text-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dp7V3ET .tooltip-text {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #dp7V3ET .tooltip-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: bold;
#    font-style: normal;
# }
# #dp7V3ET .tooltip-label {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: bold;
#    font-style: normal;
# }
#
#   </style>
#   <g id="pPv2usC">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 800.0 L600.0 800.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(23.0 34.0 ) ">
#       <g transform="translate(308.98825879334305 15.0 ) ">
#         <text class="facet-strip-text-x" text-anchor="middle" dy="0.35em">
#           <tspan>Harry</tspan>
#         </text>
#       </g>
#       <g transform="translate(50.97651758668602 30.0 ) ">
#         <line x1="23.45561283696952" y1="142.5" x2="23.45561283696952" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="95.62672925841161" y1="142.5" x2="95.62672925841161" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="167.79784567985462" y1="142.5" x2="167.79784567985462" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="239.9689621012967" y1="142.5" x2="239.9689621012967" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="312.1400785227397" y1="142.5" x2="312.1400785227397" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="384.3111949441818" y1="142.5" x2="384.3111949441818" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="456.4823113656239" y1="142.5" x2="456.4823113656239" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#       </g>
#       <g transform="translate(50.97651758668602 172.5 ) ">
#       </g>
#       <g transform="translate(50.97651758668602 30.0 ) ">
#         <line x1="0.0" y1="73.01640540076664" x2="516.023482413314" y2="73.01640540076664" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#       </g>
#       <g transform="translate(50.97651758668602 30.0 ) ">
#         <g transform="translate(0.0 140.9550746610218 ) ">
#           <g transform="translate(-3.0 0.0 ) ">
#             <text class="axis-text-y" text-anchor="end" dy="0.35em">
#               <tspan>0</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(0.0 73.01640540076664 ) ">
#           <g transform="translate(-3.0 0.0 ) ">
#             <text class="axis-text-y" text-anchor="end" dy="0.35em">
#               <tspan>5,000</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(0.0 5.07773614051149 ) ">
#           <g transform="translate(-3.0 0.0 ) ">
#             <text class="axis-text-y" text-anchor="end" dy="0.35em">
#               <tspan>10,000</tspan>
#             </text>
#           </g>
#         </g>
#       </g>
#       <g transform="translate(50.97651758668602 30.0 ) " clip-path="url(#cdsbgYq)" clip-bounds-jfx="[rect (0.0, 0.0), (516.023482413314, 142.5)]">
#         <defs>
#           <clipPath id="cdsbgYq">
#             <rect x="0.0" y="0.0" width="516.023482413314" height="142.5">
#             </rect>
#           </clipPath>
#         </defs>
#         <g>
#           <path d="M23.45561283696952 111.63274500829567 L23.45561283696952 111.63274500829567 L27.064168658041126 113.75243148921564 L30.67272447911364 110.43702442931519 L34.281280300185244 112.20342983008182 L37.88983612125776 109.18695291492648 L41.49839194233027 110.93977058184106 L45.10694776340188 110.08374334916185 L48.71550358447439 112.82846558727616 L52.324059405545995 103.28987642313633 L55.93261522661851 106.1840637336232 L59.54117104769011 108.92878597173751 L63.14972686876263 111.86373648378054 L66.75828268983514 107.3797843126037 L70.36683851090675 110.19244521997825 L73.97539433197926 111.21152525888209 L77.58395015305086 111.83656101607644 L81.19250597412338 112.54312317638309 L84.80106179519498 115.41013501916586 L88.4096176162675 112.02678929000515 L92.01817343734001 117.42111962926941 L95.62672925841161 110.08374334916185 L99.23528507948413 119.29622690085245 L102.84384090055573 117.1765404199325 L106.45239672162825 118.57607700669375 L110.06095254269985 117.55699696778993 L113.66950836377237 118.95653355455119 L117.27806418484488 118.79348074832657 L120.88662000591648 116.32051318725328 L124.495175826989 114.6763973911551 L128.1037316480606 114.79868699582356 L131.71228746913312 114.09212483551691 L135.32084329020472 106.46940614451628 L138.92939911127723 78.13898106298987 L142.53795493234975 66.79322329652727 L146.14651075342135 51.4390840437096 L149.75506657449387 25.839793466445457 L153.36362239556547 25.7718547971852 L156.97217821663799 20.62210366725786 L160.5807340377096 6.477272727272748 L164.1892898587821 18.88287373419533 L167.79784567985462 13.135262314777748 L171.40640150092622 8.69207334515707 L175.01495732199874 17.55127581669433 L178.62351314307034 15.132659191029248 L182.23206896414285 17.157231534984845 L185.84062478521446 23.896747525602166 L189.44918060628697 29.399

# %% [markdown]
# * Measuring the increase in naming diversity

# %%
total_prop_by_year_and_sex = (
    top1000.group_by(["year", "sex"])
    .agg(
        total_prop=pl.col("prop").sum()
    )
)

# %%
(
    ggplot(total_prop_by_year_and_sex, aes(x="year", y="total_prop", color="sex"))
    + geom_line(size=1)
    + scale_y_continuous(limits=[0.5, 1])
    + scale_x_continuous(format="0.0f")
    + labs(title="Total proportion of top 1000 baby names")
)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" class="plt-container" width="600.0" height="400.0">
#   <style type="text/css">
#   .plt-container {
#    font-family: Lucida Grande, sans-serif;
#    user-select: none;
#    -webkit-user-select: none;
#    -moz-user-select: none;
#    -ms-user-select: none;
# }
# text {
#    text-rendering: optimizeLegibility;
# }
# #pOAgyex .plot-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 16.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .plot-subtitle {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .plot-caption {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .legend-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .legend-item {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .axis-title-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .axis-text-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #diuIABj .axis-tooltip-text-x {
#    fill: #ffffff;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .axis-title-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 15.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .axis-text-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #diuIABj .axis-tooltip-text-y {
#    fill: #ffffff;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .facet-strip-text-x {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #pOAgyex .facet-strip-text-y {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #diuIABj .tooltip-text {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: normal;
#    font-style: normal;
# }
# #diuIABj .tooltip-title {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: bold;
#    font-style: normal;
# }
# #diuIABj .tooltip-label {
#    fill: #474747;
#    font-family: Lucida Grande, sans-serif;
#    font-size: 13.0px;
#    font-weight: bold;
#    font-style: normal;
# }
#
#   </style>
#   <g id="pOAgyex">
#     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
#     </path>
#     <g transform="translate(23.0 34.0 ) ">
#       <g transform="translate(27.034701220281416 0.0 ) ">
#         <line x1="21.89134166248823" y1="320.0" x2="21.89134166248823" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="89.24931600860691" y1="320.0" x2="89.24931600860691" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="156.60729035472468" y1="320.0" x2="156.60729035472468" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="223.96526470084336" y1="320.0" x2="223.96526470084336" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="291.32323904696113" y1="320.0" x2="291.32323904696113" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="358.6812133930798" y1="320.0" x2="358.6812133930798" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="426.0391877391976" y1="320.0" x2="426.0391877391976" y2="0.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#       </g>
#       <g transform="translate(27.034701220281416 320.0 ) ">
#         <g transform="translate(21.89134166248823 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1880</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(89.24931600860691 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1900</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(156.60729035472468 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1920</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(223.96526470084336 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1940</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(291.32323904696113 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1960</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(358.6812133930798 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>1980</tspan>
#             </text>
#           </g>
#         </g>
#         <g transform="translate(426.0391877391976 0.0 ) ">
#           <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
#           </line>
#           <g transform="translate(0.0 7.0 ) ">
#             <text class="axis-text-x" text-anchor="middle" dy="0.7em">
#               <tspan>2000</tspan>
#             </text>
#           </g>
#         </g>
#         <line x1="0.0" y1="0.0" x2="481.60951657474544" y2="0.0" stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0">
#         </line>
#       </g>
#       <g transform="translate(27.034701220281416 0.0 ) ">
#         <line x1="0.0" y1="305.45454545454544" x2="481.6095165747456" y2="305.45454545454544" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="0.0" y1="247.27272727272725" x2="481.6095165747456" y2="247.27272727272725" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="0.0" y1="189.09090909090907" x2="481.6095165747456" y2="189.09090909090907" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
#         </line>
#         <line x1="0.0" y1="130.90909090909093" x2="481.60951657
